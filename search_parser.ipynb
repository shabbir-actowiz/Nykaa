# %%
import requests
import json
cookies = {
    'bcookie': '60476f24-5483-4664-81ad-148fd1d7bd5d',
    'EXP_login-experience': 'login-experience-a',
    'EXP_new-relic-client': 'variant1',
    'EXP_rating-review-v2': 'rating-review-v2-a',
    'EXP_fe-api-migration-ab': 'fe-api-migration-a',
    'EXP_mweb-vector-search': 'mweb-vector-search-b',
    'EXP_mweb-new-user-ranking': 'sept_popularity_variant1',
    'EXP_UPDATED_AT': '1775547331516',
    'EXP_SSR_CACHE': '07ef6141d581b99cacac8db6c0608bff',
    'tm_stmp': '1776058030131',
    'rum_abMwebSort': '46',
    'EXP_add-to-cart-nudge': 'atc-a',
    'EXP_prod': 'prod-a',
    'EXP_search_dn_widgets': 'search_dn_widgets-a',
    'PHPSESSID': 'd0d906ee2a354d0cb2c4943a2aba9ab9',
    'EXP_checkout-ssr-mweb': 'variant-pci',
    'EXP_checkout-ssr-dweb': 'variant-pci',
    'EXP_login-nudge-plp': 'Variant1',
    'EXP_speculation-rule-cart-ab': 'speculation-rule-cart-a',
    'EXP_postorder_variant_ab': 'postorder_default_A',
    'EXP_gamification-nudge': 'gamification-nudge-b',
    'EXP_account_order_carousel': 'account_order_carousel-a',
    'EXP_image-search': 'image-search-a',
    '_gcl_au': '1.1.1133687320.1776058031',
    '_ga': 'GA1.1.234517355.1776058032',
    '_cs_c': '0',
    '_fbp': 'fb.1.1776058032303.259837650718476676',
    'WZRK_G': '8143bfdd82ff4e5790eb516b290b0635',
    '_hp5_event_props.2101732631': '%7B%7D',
    'NF_LN': 'true',
    'bm_ss': 'ab8e18ef4e',
    'bm_so': '89DCFBCCF52CE693D6FD253EA7825E5D32AA59763962FAA0B710BDEFB82EB6A7~...',
    'bm_sz': 'D137886A3A8F12AC5637FC21624BA6DE~...~3682629~4277553',
    'NYK_VISIT': '60476f24-5483-4664-81ad-148fd1d7bd5d~1776234485754',
    'NYK_PCOUNTER': '1',
    '_abck': '3B4A608BE5E34ED85A78DF66114D0BBD~0~...~-1~-1~1776238085~AAQAAAAF%2f%2f%2f%2f%2fyKTcpcXfyn1aJQz82N4d1QijGoQ2c9Rw81b6Kb11jWoOj%2fb5vbkRZpY0w1C0CNSlTMomuHWjwY4NZRc1GD4Iu30Ho5TPN6bovbV~-1',
    '_ga_DZ4MXZBLKH': 'GS2.1.s1776234486$o8$g1$t1776234486$j60$l0$h0',
    'NYK_ECOUNTER': '2',
    '_clck': 'ffl33j%5E2%5Eg58%5E0%5E2294',
    '_hp5_meta.2101732631': '%7B%22setPath%22%3A%7B%7D%2C%22userId%22%3A%221296054012500774%22%2C%22sessionId%22%3A%221230086506942520%22%2C%22sessionProperties%22%3A%7B%22time%22%3A1776234486628%2C%22id%22%3A%221230086506942520%22%2C%22initial_pageview_info%22%3A%7B%22time%22%3A1776234486628%2C%22id%22%3A%222695150431614155%22%2C%22title%22%3A%22Nykaa%20Fashion%20%E2%80%93%20Online%20Shopping%20of%20Clothes%20%26%20Accessories%20from%20Top%20Designers%22%2C%22url%22%3A%7B%22domain%22%3A%22www.nykaafashion.com%22%2C%22path%22%3A%22%2F%22%2C%22query%22%3A%22%22%2C%22hash%22%3A%22%22%7D%7D%2C%22search_keyword%22%3A%22%22%2C%22referrer%22%3A%22%22%2C%22utm%22%3A%7B%22source%22%3A%22%22%2C%22medium%22%3A%22%22%2C%22term%22%3A%22%22%2C%22content%22%3A%22%22%2C%22campaign%22%3A%22%22%7D%7D%7D',
    '_cs_id': 'f0cac99b-bc81-a347-acb2-fd90f239a765.1776058032.6.1776234486.1776234486.1768794831.1810222032605.1.x',
    'bm_lso': '89DCFBCCF52CE693D6FD253EA7825E5D32AA59763962FAA0B710BDEFB82EB6A7~...~1776234487384',
    '_clsk': '1xsw0u3%5E1776234487617%5E1%5E0%5El.clarity.ms%2Fcollect',
    'bm_s': '...',
    'WZRK_S_WRK-4W9-R55Z': '%7B%22p%22%3A1%2C%22s%22%3A1776234486%2C%22t%22%3A1776234606%7D',
    '_cs_s': '1.0.U.9.1776236439267',
    '_hp5_let.2101732631': '1776234643721',
}

headers = {
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'no-cache',
    'domain': 'NYKAA_FASHION',
    'pragma': 'no-cache',
    'priority': 'u=1, i',
    'referer': 'https://www.nykaafashion.com/',
    'sec-ch-ua': '"Google Chrome";v="147", "Not.A/Brand";v="8", "Chromium";v="147"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36',
    'x-csrf-token': 'K2zAZtcvYyAywhdt',
    # 'cookie': 'bcookie=60476f24-5483-4664-81ad-148fd1d7bd5d; EXP_login-experience=login-experience-a; EXP_new-relic-client=variant1; EXP_rating-review-v2=rating-review-v2-a; EXP_fe-api-migration-ab=fe-api-migration-a; EXP_mweb-vector-search=mweb-vector-search-b; EXP_mweb-new-user-ranking=sept_popularity_variant1; EXP_UPDATED_AT=1775547331516; EXP_SSR_CACHE=07ef6141d581b99cacac8db6c0608bff; tm_stmp=1776058030131; rum_abMwebSort=46; EXP_add-to-cart-nudge=atc-a; EXP_prod=prod-a; EXP_search_dn_widgets=search_dn_widgets-a; PHPSESSID=d0d906ee2a354d0cb2c4943a2aba9ab9; EXP_checkout-ssr-mweb=variant-pci; EXP_checkout-ssr-dweb=variant-pci; EXP_login-nudge-plp=Variant1; EXP_speculation-rule-cart-ab=speculation-rule-cart-a; EXP_postorder_variant_ab=postorder_default_A; EXP_gamification-nudge=gamification-nudge-b; EXP_account_order_carousel=account_order_carousel-a; EXP_image-search=image-search-a; _gcl_au=1.1.1133687320.1776058031; _ga=GA1.1.234517355.1776058032; _cs_c=0; _fbp=fb.1.1776058032303.259837650718476676; WZRK_G=8143bfdd82ff4e5790eb516b290b0635; _hp5_event_props.2101732631=%7B%7D; NF_LN=true; bm_ss=ab8e18ef4e; bm_so=89DCFBCCF52CE693D6FD253EA7825E5D32AA59763962FAA0B710BDEFB82EB6A7~...; bm_sz=D137886A3A8F12AC5637FC21624BA6DE~...~3682629~4277553; NYK_VISIT=60476f24-5483-4664-81ad-148fd1d7bd5d~1776234485754; NYK_PCOUNTER=1; _abck=3B4A608BE5E34ED85A78DF66114D0BBD~0~...~-1~-1~1776238085~AAQAAAAF%2f%2f%2f%2f%2fyKTcpcXfyn1aJQz82N4d1QijGoQ2c9Rw81b6Kb11jWoOj%2fb5vbkRZpY0w1C0CNSlTMomuHWjwY4NZRc1GD4Iu30Ho5TPN6bovbV~-1; _ga_DZ4MXZBLKH=GS2.1.s1776234486$o8$g1$t1776234486$j60$l0$h0; NYK_ECOUNTER=2; _clck=ffl33j%5E2%5Eg58%5E0%5E2294; _hp5_meta.2101732631=%7B%22setPath%22%3A%7B%7D%2C%22userId%22%3A%221296054012500774%22%2C%22sessionId%22%3A%221230086506942520%22%2C%22sessionProperties%22%3A%7B%22time%22%3A1776234486628%2C%22id%22%3A%221230086506942520%22%2C%22initial_pageview_info%22%3A%7B%22time%22%3A1776234486628%2C%22id%22%3A%222695150431614155%22%2C%22title%22%3A%22Nykaa%20Fashion%20%E2%80%93%20Online%20Shopping%20of%20Clothes%20%26%20Accessories%20from%20Top%20Designers%22%2C%22url%22%3A%7B%22domain%22%3A%22www.nykaafashion.com%22%2C%22path%22%3A%22%2F%22%2C%22query%22%3A%22%22%2C%22hash%22%3A%22%22%7D%7D%2C%22search_keyword%22%3A%22%22%2C%22referrer%22%3A%22%22%2C%22utm%22%3A%7B%22source%22%3A%22%22%2C%22medium%22%3A%22%22%2C%22term%22%3A%22%22%2C%22content%22%3A%22%22%2C%22campaign%22%3A%22%22%7D%7D%7D; _cs_id=f0cac99b-bc81-a347-acb2-fd90f239a765.1776058032.6.1776234486.1776234486.1768794831.1810222032605.1.x; bm_lso=89DCFBCCF52CE693D6FD253EA7825E5D32AA59763962FAA0B710BDEFB82EB6A7~...~1776234487384; _clsk=1xsw0u3%5E1776234487617%5E1%5E0%5El.clarity.ms%2Fcollect; bm_s=...; WZRK_S_WRK-4W9-R55Z=%7B%22p%22%3A1%2C%22s%22%3A1776234486%2C%22t%22%3A1776234606%7D; _cs_s=1.0.U.9.1776236439267; _hp5_let.2101732631=1776234643721',
}

# %%
params = {}

def get_first_suggestion(keyword):
    url = f"https://www.nykaafashion.com/rest/appapi/V2/search/suggestion"
    
    response = requests.get(
                            url,
                            params={**params, 'searchTerm': keyword},
                            cookies=cookies,
                            headers=headers,
                        )
    if response.status_code != 200:
        raise Exception(f"Failed to fetch suggestions: {response.status_code}")
    else:
        data=response.json()
        first_suggestion_name=data['response']['suggestions'][0]['suggestionWord']
        
    return first_suggestion_name

# %%
key=get_first_suggestion('sho')

headers = {
    'domain': 'NYKAA_FASHION',
    'sec-ch-ua-platform': '"Windows"',
    'x-csrf-token': 'K2zAZtcvYyAywhdt',
    'Referer': 'https://www.nykaafashion.com/catalogsearch/result/?q=Shirts+for+Women&searchType=SearchedFromSuggestions&internalSearchTerm=Shirts+for+Women&typedSearchTerm=shirts&suggestionType=query',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36',
    'sec-ch-ua': '"Google Chrome";v="147", "Not.A/Brand";v="8", "Chromium";v="147"',
    'sec-ch-ua-mobile': '?0',
}

params = {
    'PageSize': '36',
    'filter_format': 'v2',
    'apiVersion': '6',
    'currency': 'INR',
    'country_code': 'IN',
    'deviceType': 'WEBSITE',
    'sort': 'popularity',
    'device_os': 'desktop',
    'currentPage': '1',
    'sort_algo': 'ltr_pinning',
}

response = requests.get('https://www.nykaafashion.com/rest/appapi/V2/categories/products', params={**params, 'searchTerm': key }, headers=headers)
if response.status_code == 200:
    data=response.json()
    products=data.get('response', {}).get('products', [])
    print(len(products))
else:
    print(f"Failed to fetch products. Status code: {response.status_code}")
# Out:
# 36

# %%
def clean_listing_product(product):
    tag_titles = [tag.get("title") for tag in product.get("tag", []) if tag.get("title")]
    color_codes = product.get("sibling_colour_codes") or []

    return {
        "id": product.get("id"),
        "sku": product.get("sku"),
        "brand": product.get("title"),
        "name": product.get("subTitle"),
        "price": product.get("price"),
        "discounted_price": product.get("discountedPrice"),
        "discount_percent": product.get("discount"),
        "image_url": product.get("imageUrl"),
        "action_url": f"https://www.nykaafashion.com{product.get('actionUrl')}",
        "offer_message": product.get("offer_message"),
        "primary_tag": tag_titles[0] if tag_titles else None,
        "tags": tag_titles,
        "color_codes": color_codes,
        "color_count": len(color_codes),
        "is_out_of_stock": bool(product.get("isOutOfStock")),
    }

if products:
    cleaned_products = [
        clean_listing_product(product)
        for product in products
    ]

print(f"cleaned products: {len(cleaned_products)}")
print(cleaned_products[0])

output_path = f"files/output_searched_files/{key}_listing_products.json"
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(cleaned_products, f, indent=4, ensure_ascii=False)
# Out:
# cleaned products: 36
# {'id': '23335960', 'sku': 'USPOL00253707', 'brand': 'U.S. POLO ASSN.', 'name': 'Women Beige Cordela 3.0 Round Toe Lace-Ups Sneakers', 'price': 3799, 'discounted_price': 2622, 'discount_percent': 31, 'image_url': 'https://adn-static1.nykaa.com/nykdesignstudio-images/pub/media/catalog/product/d/2/d2ca7ce1FD25548A02_1.jpg?rnd=20200526195200', 'action_url': 'https://www.nykaafashion.com/u-s-polo-assn-women-beige-cordela-3-0-round-toe-lace-ups-sneakers/p/23335960', 'offer_message': None, 'primary_tag': 'BESTSELLER', 'tags': ['BESTSELLER'], 'color_codes': ['#f2e7bf', '#8e3155', '#ffffff'], 'color_count': 3, 'is_out_of_stock': False}
